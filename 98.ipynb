# %% [markdown]
# <a href="https://colab.research.google.com/github/AliciaEPFlor/LOPAL-AULAS/blob/main/98.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
soma = 10 + 10
sub = 50 - 50
mult = 10 * 2
div = 100 / 10
rest_div = 5 % 3
div_int = 5 // 3
print(f"O resto da divisão é:{rest_div}")
print(f"O resto da divisão inteira é:{div_int}")
print(f"O resto da divisão fração é:{div_int} {rest_div}/3")

# print(f"Valor do soma é:{soma}")
print(f"Valor da subtração e:{sub}")
print(f"Valor da multiplicação é:{mult}")
print(f"Valor da divisão é:{div}")

nome = input("Digite seu nome:")
print(f"Ola {nome}")
# Out:
# O resto da divisão é:2
# O resto da divisão inteira é:1
# O resto da divisão fração é:1 2/3
# Valor da subtração e:0
# Valor da multiplicação é:20
# Valor da divisão é:10.0
# Digite seu nome:chupa meu pau
# Ola chupa meu pau

# %%
dividendo = int(input("Digite o dividendo: "))
divisor = int(input("Digite seu divisor: "))
div_int = dividendo // divisor
rest_div = dividendo % divisor
print("O valor é: {} {} {}/{}"format(div_int, rest_div, divisor))

# %%
# Potencia de um numero
9 ** 2
# Out:
# 81

# %%
# Raiz de um numero
81 ** (1/2)
81 ** 0,5
# Out:
# (1, 5)

# %%
# Operadores Booleanos
6 == 7
#Comparação de igualdade
# Out:
# False

# %%
# Operadores Booleanos
6 != 7
#Comparação de diferença
# Out:
# True

# %%
# Operadores Booleanos
"Maria" = "João"
# Out:
# True

# %%
7 > 5
# Out:
# True

# %%
7 < 5
# Out:
# False

# %%
7 >= 5
# Out:
# True

# %%
7 <= 5
# Out:
# False

# %%
import math
pi = math.atan (1)*4
print(f"pi:.2f")
# Out:
# pi:.2f
